# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_selection import RFECV
from sklearn.svm import OneClassSVM
from sklearn.model_selection import KFold, train_test_split, cross_val_score
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

import optuna

# %% [markdown]
# # Create an example dataset
#
# Swap out with your dataset.
# The dataset here consists of a single gaussian-sampled inlier cluster with some randomly sampled outliers around it.
# For `n_features = 2` you can plot it. :)

# %%
n_good_samples = 500
n_bad_samples = 40
n_features = 10

np.random.seed(42)
# Generate inliers
X, y = make_blobs(n_samples=n_good_samples, centers=[(np.random.randn(n_features))], n_features=n_features, random_state=42)
# Generate random outliers
X_outliers = np.random.uniform(low=-10, high=10, size=(n_bad_samples, n_features))

if n_features == 2:
    plt.plot(X[:, 0], X[:, 1], 'o', label='inliers')
    plt.plot(X_outliers[:, 0], X_outliers[:, 1], 'x', label='outliers')

X = np.concatenate([X, X_outliers], axis=0)
y = np.concatenate([y, np.ones(X_outliers.shape[0]).astype(int)], axis=0)

# %% [markdown]
# # Split, prepare and inspect the data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# My code works with pandas inputs
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)
y_train = pd.Series(y_train)
y_test = pd.Series(y_test)

# %%
X_train
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.747207  0.208184 -0.032336  1.755284  0.058919 -0.948488  3.444987
# 1    1.083977 -0.343892  0.730521  0.794858  1.513984  0.805925  0.839442
# 2    0.280754  0.799213  2.282755  2.834723 -1.326295 -0.487813  1.234048
# 3    2.666651 -1.561947 -1.204154  2.306620 -0.912796 -0.552374  0.798056
# 4    0.013653  0.008529  2.259909  2.419869 -0.502684 -1.125329 -0.572603
# ..        ...       ...       ...       ...       ...       ...       ...
# 427 -0.690279  0.919550  0.058576  0.587434 -0.412071 -1.146948  1.161782
# 428  2.301062 -0.329168  1.367446  0.229757 -1.190590  0.238269  3.063329
# 429 -1.349474 -1.067775 -0.848841  0.873006 -0.317591 -1.683782  0.657353
# 430 -8.576227 -3.620487  6.897506 -9.534561  6.289370 -4.362905 -7.636703
# 431  1.297124  0.616027  1.836602  2.231334  0.117295  0.836013  1.552692
#
#             7         8         9
# 0    1.241268 -1.660778  1.199114
# 1   -0.567176 -0.855147  0.977063
# 2    1.256689  0.216879 -0.296333
# 3    0.507635  1.129064  1.344689
# 4    0.048281 -0.680605 -0.444619
# ..        ...       ...       ...
# 427  1.111489 -0.121133 -0.355270
# 428  1.123048 -0.782532  0.541851
# 429 -0.236523 -0.262207  0.611904
# 430  3.934743  2.578857  7.549440
# 431 -0.114440 -0.632541 -0.202343
#
# [432 rows x 10 columns]

# %% [markdown]
# Note the distribution of the anomaly samples

# %%
y_train.value_counts()
# Out:
# 0    400
# 1     32
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    100
# 1      8
# Name: count, dtype: int64

# %% [markdown]
# # One-class classification with RFECV feature selection and hyperparameter optimization using Optuna

# %% [markdown]
# ## Required Utilities

# %%
# A version of the OneClassSVM that outputs 0 = good and 1 = bad instead of -1 = bad and 1 = 0
class BinaryOneClassSVM(OneClassSVM):
    def predict(self, X):
        y_pred = super().predict(X)
        return (y_pred == -1).astype(int) # -1 -> 1, 1 -> 0

# Special kfold for one-class classification with only good samples in the training splits
def split_with_one_class_KFold(X, y, n_splits, shuffle, random_state):
    # Note that StratifiedKFold would cause data leakage because it splits based on the target which is supposed to be one-class
    kfold = KFold(n_splits=n_splits, shuffle=shuffle, random_state=random_state)
    splits = kfold.split(X) # Iterator of (train_index, valid_index) tuples
    return [(train_index[y.iloc[train_index] == 0], valid_index) for train_index, valid_index in splits]

# %% [markdown]
# ## Feature Selection

# %%
splits = split_with_one_class_KFold(X_train, y_train, n_splits=3, shuffle=True, random_state=42) 

classifier = Pipeline([
    # By putting the scaler into a Pipeline with the clf, the scaler will always be 
    # fitted correctly on the train data in every fold of the CV inside the RFECV
    ("scaler", StandardScaler()),
     # Only linear kernel is supported for feature selection. Needs to be *Binary*OneClassSVM for RFECV.
    ("classifier", BinaryOneClassSVM(kernel="linear"))
])

# Perform RFECV
importance_getter = "named_steps.classifier.coef_" # Important when using a Pipeline
rfecv = RFECV(classifier, cv=splits, n_jobs=3, scoring="f1", importance_getter=importance_getter)
X_train = pd.DataFrame(rfecv.fit_transform(X_train, y_train), index=X_train.index) # X_train now has less features from here on

# %%
X_train
# Out:
#             0         1         2         3         4
# 0   -0.032336  1.755284  0.058919  3.444987  1.199114
# 1    0.730521  0.794858  1.513984  0.839442  0.977063
# 2    2.282755  2.834723 -1.326295  1.234048 -0.296333
# 3   -1.204154  2.306620 -0.912796  0.798056  1.344689
# 4    2.259909  2.419869 -0.502684 -0.572603 -0.444619
# ..        ...       ...       ...       ...       ...
# 427  0.058576  0.587434 -0.412071  1.161782 -0.355270
# 428  1.367446  0.229757 -1.190590  3.063329  0.541851
# 429 -0.848841  0.873006 -0.317591  0.657353  0.611904
# 430  6.897506 -9.534561  6.289370 -7.636703  7.549440
# 431  1.836602  2.231334  0.117295  1.552692 -0.202343
#
# [432 rows x 5 columns]

# %% [markdown]
# ## Hyperparameter optimization

# %%
def objective(trial, X_train, y_train):
    # Hyperparameters for OneClassSVM (feel free to add more)
    nu = trial.suggest_float("nu", 0.01, 0.5)
    gamma = trial.suggest_float("gamma", 0.01, 0.5)
    kernel = trial.suggest_categorical("kernel", ["linear", "rbf", "poly", "sigmoid"])

    # Create the classifier
    classifier = Pipeline([
        ("scaler", StandardScaler()),
        ("classifier", BinaryOneClassSVM(nu=nu, gamma=gamma, kernel=kernel))
    ])

    # Perform cross-validation
    splits = split_with_one_class_KFold(X_train, y_train, n_splits=5, shuffle=True, random_state=42)
    return cross_val_score(classifier, X_train, y_train, cv=splits, scoring="f1").mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(lambda trial: objective(trial, X_train, y_train), n_trials=200)
# Out:
# [I 2024-10-17 15:01:42,576] A new study created in memory with name: no-name-4171638c-cf78-417a-baa1-6a2898375806
# [I 2024-10-17 15:01:42,595] Trial 0 finished with value: 0.17245526138383283 and parameters: {'nu': 0.11997693416829158, 'gamma': 0.35559424893914277, 'kernel': 'poly'}. Best is trial 0 with value: 0.17245526138383283.
# [I 2024-10-17 15:01:42,616] Trial 1 finished with value: 0.2996023391812866 and parameters: {'nu': 0.32610577685480063, 'gamma': 0.26871949911833565, 'kernel': 'rbf'}. Best is trial 1 with value: 0.2996023391812866.
# [I 2024-10-17 15:01:42,636] Trial 2 finished with value: 0.3228138528138528 and parameters: {'nu': 0.24727189668973953, 'gamma': 0.3028232956615806, 'kernel': 'rbf'}. Best is trial 2 with value: 0.3228138528138528.
# [I 2024-10-17 15:01:42,656] Trial 3 finished with value: 0.30161036969547605 and parameters: {'nu': 0.06545331951097559, 'gamma': 0.4427470397234579, 'kernel': 'rbf'}. Best is trial 2 with value: 0.3228138528138528.
# [I 2024-10-17 15:01:42,670] Trial 4 finished with value: 0.11013440388440388 and parameters: {'nu': 0.059645907221467676, 'gamma': 0.23295906065398383, 'kernel': 'linear'}. Best is trial 2 with value: 0.3228138528138528.
# [I 2024-10-17 15:01:42,690] Trial 5 finished with value: 0.27290982701509015 and parameters: {'nu': 0.1939646443492943, 'gamma': 0.07983563955177451, 'kernel': 'sigmoid'}. Best is trial 2 with value: 0.3228138528138528.
# [I 2024-10-17 15:01:42,706] Trial 6 finished with value: 0.13034730472881856 and parameters: {'nu': 0.26021568651895005, 'gamma': 0.25855157850917904, 'kernel': 'linear'}. Best is trial 2 with value: 0.3228138528138528.
# [I 2024-10-17 15:01:42,723] Trial 7 finished with value: 0.4225448159758504 and parameters: {'nu': 0.039302297225216415, 'gamma': 0.2505967928372897, 'kernel': 'rbf'}. Best is trial 7 with value: 0.4225448159758504.
# [I 2024-10-17 15:01:42,741] Trial 8 finished with value: 0.15877053736188 and parameters: {'nu': 0.01932388650969434, 'gamma': 0.27818206115711, 'kernel': 'poly'}. Best is trial 7 with value: 0.4225448159758504.
# [I 2024-10-17 15:01:42,765] Trial 9 finished with value: 0.14228010268332847 and parameters: {'nu': 0.4200144357078506, 'gamma': 0.46911396627781127, 'kernel': 'sigmoid'}. Best is trial 7 with value: 0.4225448159758504.
# [I 2024-10-17 15:01:42,792] Trial 10 finished with value: 0.2570670863204523 and parameters: {'nu': 0.4434867239207312, 'gamma': 0.12360507619317035, 'kernel': 'rbf'}. Best is trial 7 with value: 0.4225448159758504.
# [I 2024-10-17 15:01:42,814] Trial 11 finished with value: 0.4031689443454149 and parameters: {'nu': 0.19570586576670837, 'gamma': 0.1584348694376375, 'kernel': 'rbf'}. Best is trial 7 with value: 0.4225448159758504.
# [I 2024-10-17 15:01:42,837] Trial 12 finished with value: 0.43279216617060035 and parameters: {'nu': 0.15438288344234602, 'gamma': 0.16440348060620488, 'kernel': 'rbf'}. Best is trial 12 with value: 0.43279216617060035.
# [I 2024-10-17 15:01:42,857] Trial 13 finished with value: 0.5057040962667096 and parameters: {'nu': 0.1310689917991386, 'gamma': 0.01354668290121483, 'kernel': 'rbf'}. Best is trial 13 with value: 0.5057040962667096.
# [I 2024-10-17 15:01:42,877] Trial 14 finished with value: 0.5057040962667096 and parameters: {'nu': 0.13746791587758692, 'gamma': 0.016582026980732644, 'kernel': 'rbf'}. Best is trial 13 with value: 0.5057040962667096.
# [I 2024-10-17 15:01:42,898] Trial 15 finished with value: 0.5057040962667096 and parameters: {'nu': 0.14210996055066516, 'gamma': 0.014592844776451576, 'kernel': 'rbf'}. Best is trial 13 with value: 0.5057040962667096.
# [I 2024-10-17 15:01:42,917] Trial 16 finished with value: 0.09254243409172987 and parameters: {'nu': 0.33907161953934717, 'gamma': 0.01608441207168592, 'kernel': 'poly'}. Best is trial 13 with value: 0.5057040962667096.
# [I 2024-10-17 15:01:42,936] Trial 17 finished with value: 0.08020004839880615 and parameters: {'nu': 0.10913655179661395, 'gamma': 0.07750551268474153, 'kernel': 'linear'}. Best is trial 13 with value: 0.5057040962667096.
# [I 2024-10-17 15:01:42,960] Trial 18 finished with value: 0.15766081871345028 and parameters: {'nu': 0.22943184024104768, 'gamma': 0.06977495523890245, 'kernel': 'sigmoid'}. Best is trial 13 with value: 0.5057040962667096.
# [I 2024-10-17 15:01:42,981] Trial 19 finished with value: 0.5109125999448579 and parameters: {'nu': 0.09247924704380517, 'gamma': 0.1812969045102048, 'kernel': 'rbf'}. Best is trial 19 with value: 0.5109125999448579.
# [I 2024-10-17 15:01:43,002] Trial 20 finished with value: 0.49605949605949606 and parameters: {'nu': 0.08994623128633979, 'gamma': 0.19632973189439956, 'kernel': 'rbf'}. Best is trial 19 with value: 0.5109125999448579.
# [I 2024-10-17 15:01:43,023] Trial 21 finished with value: 0.4526227795193313 and parameters: {'nu': 0.1688138031286916, 'gamma': 0.04835115834593379, 'kernel': 'rbf'}. Best is trial 19 with value: 0.5109125999448579.
# [I 2024-10-17 15:01:43,044] Trial 22 finished with value: 0.5219166395209953 and parameters: {'nu': 0.0949311789548192, 'gamma': 0.10034865007795801, 'kernel': 'rbf'}. Best is trial 22 with value: 0.5219166395209953.
# [I 2024-10-17 15:01:43,064] Trial 23 finished with value: 0.5371474087517645 and parameters: {'nu': 0.07893516808815587, 'gamma': 0.1278034760230376, 'kernel': 'rbf'}. Best is trial 23 with value: 0.5371474087517645.
# [I 2024-10-17 15:01:43,083] Trial 24 finished with value: 0.5974331550802139 and parameters: {'nu': 0.016098622609904356, 'gamma': 0.11214768419934583, 'kernel': 'rbf'}. Best is trial 24 with value: 0.5974331550802139.
# [I 2024-10-17 15:01:43,102] Trial 25 finished with value: 0.5614103542021163 and parameters: {'nu': 0.018791581950491708, 'gamma': 0.1427881722040933, 'kernel': 'rbf'}. Best is trial 24 with value: 0.5974331550802139.
# [I 2024-10-17 15:01:43,122] Trial 26 finished with value: 0.17156761412575366 and parameters: {'nu': 0.015218603018177025, 'gamma': 0.12580065213590405, 'kernel': 'poly'}. Best is trial 24 with value: 0.5974331550802139.
# [I 2024-10-17 15:01:43,138] Trial 27 finished with value: 0.12491570262756702 and parameters: {'nu': 0.011561091289098251, 'gamma': 0.20765736776798943, 'kernel': 'linear'}. Best is trial 24 with value: 0.5974331550802139.
# [I 2024-10-17 15:01:43,157] Trial 28 finished with value: 0.31919844861021335 and parameters: {'nu': 0.053727237309311934, 'gamma': 0.13417521802194968, 'kernel': 'sigmoid'}. Best is trial 24 with value: 0.5974331550802139.
# [I 2024-10-17 15:01:43,179] Trial 29 finished with value: 0.11572871572871572 and parameters: {'nu': 0.06864235731932807, 'gamma': 0.36557035733733567, 'kernel': 'poly'}. Best is trial 24 with value: 0.5974331550802139.
# [I 2024-10-17 15:01:43,205] Trial 30 finished with value: 0.2402242952677937 and parameters: {'nu': 0.4869515356031362, 'gamma': 0.14552831918899942, 'kernel': 'rbf'}. Best is trial 24 with value: 0.5974331550802139.
# [I 2024-10-17 15:01:43,227] Trial 31 finished with value: 0.5219166395209953 and parameters: {'nu': 0.10011642436472623, 'gamma': 0.09722572567409624, 'kernel': 'rbf'}. Best is trial 24 with value: 0.5974331550802139.
# [I 2024-10-17 15:01:43,247] Trial 32 finished with value: 0.5974331550802139 and parameters: {'nu': 0.04254215365415471, 'gamma': 0.10865928183094112, 'kernel': 'rbf'}. Best is trial 24 with value: 0.5974331550802139.
# [I 2024-10-17 15:01:43,266] Trial 33 finished with value: 0.5974331550802139 and parameters: {'nu': 0.03743600271827435, 'gamma': 0.11113702275097312, 'kernel': 'rbf'}. Best is trial 24 with value: 0.5974331550802139.
# [I 2024-10-17 15:01:43,285] Trial 34 finished with value: 0.6586749482401656 and parameters: {'nu': 0.045943694518856895, 'gamma': 0.053701713823131124, 'kernel': 'rbf'}. Best is trial 34 with value: 0.6586749482401656.
# [I 2024-10-17 15:01:43,304] Trial 35 finished with value: 0.6514285714285715 and parameters: {'nu': 0.05061058067446805, 'gamma': 0.05300959512799791, 'kernel': 'rbf'}. Best is trial 34 with value: 0.6586749482401656.
# [I 2024-10-17 15:01:43,323] Trial 36 finished with value: 0.6392857142857142 and parameters: {'nu': 0.055009191124339996, 'gamma': 0.04635733522939798, 'kernel': 'rbf'}. Best is trial 34 with value: 0.6586749482401656.
# [I 2024-10-17 15:01:43,346] Trial 37 finished with value: 0.3325555166987235 and parameters: {'nu': 0.3014087316834435, 'gamma': 0.03701239197822703, 'kernel': 'rbf'}. Best is trial 34 with value: 0.6586749482401656.
# [I 2024-10-17 15:01:43,364] Trial 38 finished with value: 0.14641300964830375 and parameters: {'nu': 0.06350003126640325, 'gamma': 0.05268554888236891, 'kernel': 'linear'}. Best is trial 34 with value: 0.6586749482401656.
# [I 2024-10-17 15:01:43,387] Trial 39 finished with value: 0.3443556801878179 and parameters: {'nu': 0.17853973489850494, 'gamma': 0.3233190977242761, 'kernel': 'rbf'}. Best is trial 34 with value: 0.6586749482401656.
# [I 2024-10-17 15:01:43,409] Trial 40 finished with value: 0.2281765018607124 and parameters: {'nu': 0.11917038754342814, 'gamma': 0.06493989220504572, 'kernel': 'sigmoid'}. Best is trial 34 with value: 0.6586749482401656.
# [I 2024-10-17 15:01:43,427] Trial 41 finished with value: 0.619244970715559 and parameters: {'nu': 0.04719082552208392, 'gamma': 0.08593389801477366, 'kernel': 'rbf'}. Best is trial 34 with value: 0.6586749482401656.
# [I 2024-10-17 15:01:43,447] Trial 42 finished with value: 0.6327731092436976 and parameters: {'nu': 0.044116663910205786, 'gamma': 0.0879903625359372, 'kernel': 'rbf'}. Best is trial 34 with value: 0.6586749482401656.
# [I 2024-10-17 15:01:43,466] Trial 43 finished with value: 0.619244970715559 and parameters: {'nu': 0.05394475250294271, 'gamma': 0.0834596954494381, 'kernel': 'rbf'}. Best is trial 34 with value: 0.6586749482401656.
# [I 2024-10-17 15:01:43,486] Trial 44 finished with value: 0.66307055263577 and parameters: {'nu': 0.041441983640419976, 'gamma': 0.049889390050865595, 'kernel': 'rbf'}. Best is trial 44 with value: 0.66307055263577.
# [I 2024-10-17 15:01:43,506] Trial 45 finished with value: 0.6074959742351047 and parameters: {'nu': 0.07884510442985547, 'gamma': 0.040207390635709335, 'kernel': 'rbf'}. Best is trial 44 with value: 0.66307055263577.
# [I 2024-10-17 15:01:43,531] Trial 46 finished with value: 0.3087440990728371 and parameters: {'nu': 0.11958365448074694, 'gamma': 0.4156132283797196, 'kernel': 'rbf'}. Best is trial 44 with value: 0.66307055263577.
# [I 2024-10-17 15:01:43,551] Trial 47 finished with value: 0.1402020202020202 and parameters: {'nu': 0.03534054608645494, 'gamma': 0.04530799599790154, 'kernel': 'poly'}. Best is trial 44 with value: 0.66307055263577.
# [I 2024-10-17 15:01:43,571] Trial 48 finished with value: 0.6064244578950462 and parameters: {'nu': 0.0691060634691438, 'gamma': 0.06228352183535168, 'kernel': 'rbf'}. Best is trial 44 with value: 0.66307055263577.
# [I 2024-10-17 15:01:43,594] Trial 49 finished with value: 0.39811652259470093 and parameters: {'nu': 0.21498512302781456, 'gamma': 0.03168999134448826, 'kernel': 'rbf'}. Best is trial 44 with value: 0.66307055263577.
# [I 2024-10-17 15:01:43,616] Trial 50 finished with value: 0.11334288101205395 and parameters: {'nu': 0.3779768682493787, 'gamma': 0.032312800171633654, 'kernel': 'linear'}. Best is trial 44 with value: 0.66307055263577.
# [I 2024-10-17 15:01:43,635] Trial 51 finished with value: 0.6572463768115943 and parameters: {'nu': 0.03845966997962647, 'gamma': 0.08648301325149838, 'kernel': 'rbf'}. Best is trial 44 with value: 0.66307055263577.
# [I 2024-10-17 15:01:43,654] Trial 52 finished with value: 0.6605797101449276 and parameters: {'nu': 0.03471297232291612, 'gamma': 0.0834008777875816, 'kernel': 'rbf'}. Best is trial 44 with value: 0.66307055263577.
# [I 2024-10-17 15:01:43,674] Trial 53 finished with value: 0.6681987577639751 and parameters: {'nu': 0.03050785579164366, 'gamma': 0.06027084653113818, 'kernel': 'rbf'}. Best is trial 53 with value: 0.6681987577639751.
# [I 2024-10-17 15:01:43,693] Trial 54 finished with value: 0.66307055263577 and parameters: {'nu': 0.0303780496500604, 'gamma': 0.06906025360736386, 'kernel': 'rbf'}. Best is trial 53 with value: 0.6681987577639751.
# [I 2024-10-17 15:01:43,712] Trial 55 finished with value: 0.2163636363636364 and parameters: {'nu': 0.030820278402791144, 'gamma': 0.22230453518430027, 'kernel': 'sigmoid'}. Best is trial 53 with value: 0.6681987577639751.
# [I 2024-10-17 15:01:43,732] Trial 56 finished with value: 0.6687848383500558 and parameters: {'nu': 0.026517969864313373, 'gamma': 0.06788996435588522, 'kernel': 'rbf'}. Best is trial 56 with value: 0.6687848383500558.
# [I 2024-10-17 15:01:43,754] Trial 57 finished with value: 0.5282486323335219 and parameters: {'nu': 0.07866617623990332, 'gamma': 0.1645052141643657, 'kernel': 'rbf'}. Best is trial 56 with value: 0.6687848383500558.
# [I 2024-10-17 15:01:43,772] Trial 58 finished with value: 0.7799498746867167 and parameters: {'nu': 0.02683156761601308, 'gamma': 0.013675568040487862, 'kernel': 'rbf'}. Best is trial 58 with value: 0.7799498746867167.
 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,263] Trial 183 finished with value: 0.8209022556390977 and parameters: {'nu': 0.010056695935041968, 'gamma': 0.02003569531528781, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,283] Trial 184 finished with value: 0.6933069828722002 and parameters: {'nu': 0.01041884110734199, 'gamma': 0.03994365894620176, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,301] Trial 185 finished with value: 0.7195772038792633 and parameters: {'nu': 0.03233319722603514, 'gamma': 0.021025350233703884, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,321] Trial 186 finished with value: 0.09405180840664712 and parameters: {'nu': 0.02533066232838637, 'gamma': 0.029675249070068875, 'kernel': 'poly'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,340] Trial 187 finished with value: 0.66307055263577 and parameters: {'nu': 0.03979605082371103, 'gamma': 0.04732671732150927, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,359] Trial 188 finished with value: 0.8066165413533835 and parameters: {'nu': 0.011167448762590787, 'gamma': 0.02031004426057574, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,379] Trial 189 finished with value: 0.7284878863826231 and parameters: {'nu': 0.019201245034437514, 'gamma': 0.02885184031411966, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,401] Trial 190 finished with value: 0.44848484848484843 and parameters: {'nu': 0.17455082545637318, 'gamma': 0.044204732145886584, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,420] Trial 191 finished with value: 0.7877930119416188 and parameters: {'nu': 0.018615404463648094, 'gamma': 0.018171933031209994, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,439] Trial 192 finished with value: 0.856043956043956 and parameters: {'nu': 0.010108315754845464, 'gamma': 0.010328563335314619, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,460] Trial 193 finished with value: 0.8209022556390977 and parameters: {'nu': 0.01059670154986398, 'gamma': 0.019337845949324785, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,479] Trial 194 finished with value: 0.7473602420970842 and parameters: {'nu': 0.028052273617003215, 'gamma': 0.020008685996741098, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,500] Trial 195 finished with value: 0.7361403508771929 and parameters: {'nu': 0.010481478158618801, 'gamma': 0.032250342780294504, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,525] Trial 196 finished with value: 0.7584713532081953 and parameters: {'nu': 0.027165826785359677, 'gamma': 0.018347769404974776, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,553] Trial 197 finished with value: 0.7284878863826231 and parameters: {'nu': 0.019166349921345055, 'gamma': 0.02801256111523941, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,572] Trial 198 finished with value: 0.12595974739902777 and parameters: {'nu': 0.010085712439234172, 'gamma': 0.010864052928682763, 'kernel': 'linear'}. Best is trial 120 with value: 0.8750915750915752.
# [I 2024-10-17 15:01:46,593] Trial 199 finished with value: 0.6742593638245811 and parameters: {'nu': 0.035287046955118376, 'gamma': 0.037907158312614625, 'kernel': 'rbf'}. Best is trial 120 with value: 0.8750915750915752.

# %% [markdown]
# ## Refit and evaluation of the best model

# %%
best_params = study.best_params

# %%
# Remove all bad (positive class) samples from the training data for one-class classification
X_train = X_train[y_train == 0]
y_train = y_train[y_train == 0]

# %%
# RFECV is already fit and X_train already transformed, so the other steps are also fit beforehand.
# Final pipeline object can be used for predicting.

scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), index=X_train.index, columns=X_train.columns)

base_classifier = BinaryOneClassSVM(**best_params)
base_classifier.fit(X_train, y_train)

pipeline_steps = []
pipeline_steps.append(('use_RFECV', rfecv))
pipeline_steps.append(('scaler', scaler)) # Scaler has to come after feature selection
pipeline_steps.append(('classifier', base_classifier))
classifier = Pipeline(pipeline_steps)

# %%
# Evaluate on the test set
y_pred = classifier.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       100
#            1       0.80      1.00      0.89         8
#
#     accuracy                           0.98       108
#    macro avg       0.90      0.99      0.94       108
# weighted avg       0.99      0.98      0.98       108
